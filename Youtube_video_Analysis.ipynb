# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns 
import scipy.stats as sat

# %%
categories= pd.read_json("C:/Users/manoj_paliwal/Desktop/deepika/python/youtube analysis project/IN_category_id.json","r",encoding="utf8")
categories
# Out:
# <ipython-input-502-a2130117c5ea>:1: FutureWarning: Starting with Pandas version 2.0 all arguments of read_json except for the argument 'path_or_buf' will be keyword-only
#   categories= pd.read_json("C:/Users/manoj_paliwal/Desktop/deepika/python/youtube analysis project/IN_category_id.json","r",encoding="utf8")
#                                  kind                         etag  \
# 0   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 1   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 2   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 3   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 4   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 5   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 6   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# 7   youtube#videoCategoryListResponse  kBCr3I9kLHHU79W4Ip5196LDptI
# ...

# %%
categories['items'][1]
# Out:
# {'kind': 'youtube#videoCategory',
#  'etag': '5XGylIs7zkjHh5940dsT5862m1Y',
#  'id': '2',
#  'snippet': {'title': 'Autos & Vehicles',
#   'assignable': True,
#   'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}

# %%
##creating dictionary for json file for category and category &catecory id
category_dict= {}
for i in categories['items']:
    category_dict[i['id']]=i['snippet']['title']

# %%
#reading csv file
df=pd.read_csv(r'C:/Users/manoj_paliwal/Desktop/deepika/python/youtube analysis project/IN_youtube_trending_data.csv')

# %%
df.head(2).T
# Out:
#                                                                    0  \
# video_id                                                 Iot0eF6EoNA
# title              Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# publishedAt                                     2020-08-12T04:31:41Z
# channelId                                   UCGqvJPRcv7aVFun-eTsatcA
# channelTitle                                            FoxStarHindi
# categoryId                                                        24
# trending_date                                   2020-08-12T00:00:00Z
# tags               sadak|sadak 2|mahesh bhatt|vishesh films|pooja...
# view_count                                                   9885899
# likes                                                         224925
# dislikes                                                     3979409
# comment_count                                                 350210
# thumbnail_link        https://i.ytimg.com/vi/Iot0eF6EoNA/default.jpg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152593 entries, 0 to 152592
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           152593 non-null  object
#  1   title              152593 non-null  object
#  2   publishedAt        152593 non-null  object
#  3   channelId          152593 non-null  object
#  4   channelTitle       152592 non-null  object
#  5   categoryId         152593 non-null  int64
#  6   trending_date      152593 non-null  object
#  7   tags               152593 non-null  object
#  8   view_count         152593 non-null  int64
#  9   likes              152593 non-null  int64
#  10  dislikes           152593 non-null  int64
#  11  comment_count      152593 non-null  int64
#  12  thumbnail_link     152593 non-null  object
#  13  comments_disabled  152593 non-null  bool
#  14  ratings_disabled   152593 non-null  bool
# ...

# %% [markdown]
# **Statistical Analysis**[5 numbur summery]

# %%
df.describe()
# Out:
#           categoryId    view_count         likes      dislikes  comment_count
# count  152593.000000  1.525930e+05  1.525930e+05  1.525930e+05   1.525930e+05
# mean       20.928005  3.148897e+06  1.695163e+05  3.842192e+03   9.988589e+03
# std         5.958950  7.553347e+06  4.454034e+05  9.236131e+04   8.708685e+04
# min         1.000000  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        20.000000  4.568570e+05  1.737800e+04  0.000000e+00   4.080000e+02
# 50%        24.000000  1.100973e+06  5.066700e+04  3.830000e+02   1.330000e+03
# 75%        24.000000  2.801690e+06  1.464980e+05  1.931000e+03   4.613000e+03
# max        29.000000  2.644074e+08  1.611524e+07  1.234147e+07   6.738565e+06

# %%
##checking for missing values
df.isnull().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          16773
# dtype: int64

# %% [markdown]
# checking random video id

# %%
df[df.video_id=='x-KbnJ9fvJc']
# Out:
#          video_id                                              title  \
# 1     x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 172   x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 352   x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 531   x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 714   x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 923   x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 1140  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 1375  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 1618  x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
#
#                publishedAt                 channelId    channelTitle  \
# 1     2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g  Rehaan Records
# 172   2020-08-11T09:00:11Z  UCm9SZAl03Rev9sFwloCdz1g  Rehaan Records
# ...

# %%
df.video_id.nunique()
# Out:
# 46294

# %%
df.title.nunique()
# Out:
# 46836

# %%
df.channelId.nunique()
# Out:
# 3877

# %%
df.head(2).T
# Out:
#                                                                    0  \
# video_id                                                 Iot0eF6EoNA
# title              Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# publishedAt                                     2020-08-12T04:31:41Z
# channelId                                   UCGqvJPRcv7aVFun-eTsatcA
# channelTitle                                            FoxStarHindi
# categoryId                                                        24
# trending_date                                   2020-08-12T00:00:00Z
# tags               sadak|sadak 2|mahesh bhatt|vishesh films|pooja...
# view_count                                                   9885899
# likes                                                         224925
# dislikes                                                     3979409
# comment_count                                                 350210
# thumbnail_link        https://i.ytimg.com/vi/Iot0eF6EoNA/default.jpg
# ...

# %% [markdown]
# **maximum views & mimnimum views**

# %%
df_maxiview = df.sort_values('view_count',ascending=False).drop_duplicates(['video_id'])

df_maxiview.head(5)
# Out:
#            video_id                                              title  \
# 52057   WMweEpGlu_U                   BTS (방탄소년단) 'Butter' Official MV
# 3619    gdZLi9oWNZg                 BTS (방탄소년단) 'Dynamite' Official MV
# 64049   DUwlGduupRI  Filhaal2 Mohabbat | Akshay Kumar Ft Nupur Sano...
# 143385  gQlMMD8auMs                       BLACKPINK - ‘Pink Venom’ M/V
# 4735    vRXZj0DzXIA    BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V
#
#                  publishedAt                 channelId        channelTitle  \
# 52057   2021-05-21T03:46:13Z  UC3IZKseVpdzPSBaWxBxundA         HYBE LABELS
# 3619    2020-08-21T03:58:10Z  UC3IZKseVpdzPSBaWxBxundA      Big Hit Labels
# 64049   2021-07-06T09:30:02Z  UC783dnzJqf2ghHp_pFLYbGA  DM - Desi Melodies
# 143385  2022-08-19T04:00:13Z  UCOmHUn--16B90oW2L6FRR3A           BLACKPINK
# 4735    2020-08-28T04:00:11Z  UCOmHUn--16B90oW2L6FRR3A           BLACKPINK
#
#         categoryId         trending_date  \
# 52057           10  2021-05-30T00:00:00Z
# ...

# %%
df_miniview=df.sort_values('view_count',ascending=True).drop_duplicates(['video_id'])
df_miniview.head(5).T
# Out:
#                                                                47639  \
# video_id                                                 hAxqygRdM4g
# title                                          Earth Day 2021 Doodle
# publishedAt                                     2021-04-21T11:00:14Z
# channelId                                   UCdq61m8s_48EhJ5OM_MCeGw
# channelTitle                                           GoogleDoodles
# categoryId                                                         1
# trending_date                                   2021-04-27T00:00:00Z
# tags                                                          [None]
# view_count                                                         0
# likes                                                              0
# dislikes                                                           0
# comment_count                                                      0
# thumbnail_link        https://i.ytimg.com/vi/hAxqygRdM4g/default.jpg
# ...

# %% [markdown]
# **append categories to all dataframes**

# %%
cat_vid=categories['items'][1]['snippet']['title']
cat_vid
# Out:
# 'Autos & Vehicles'

# %%
##define function
def fecth_video_category(value):
    return categories['items'][value]['snippet']['title']

# %%
df['video_category']=df.categoryId.apply(fecth_video_category)

# %% [markdown]
# df_maxViews stores the last occurance of VideoID.

# %%
df_maxiview['video_category']=df_maxiview.categoryId.apply(fecth_video_category)
df_miniview['video_category']=df_miniview.categoryId.apply(fecth_video_category)

# %%
df_maxiview.head(2).T
# Out:
#                                                                52057  \
# video_id                                                 WMweEpGlu_U
# title                               BTS (방탄소년단) 'Butter' Official MV
# publishedAt                                     2021-05-21T03:46:13Z
# channelId                                   UC3IZKseVpdzPSBaWxBxundA
# channelTitle                                             HYBE LABELS
# categoryId                                                        10
# trending_date                                   2021-05-30T00:00:00Z
# tags                                 BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄
# view_count                                                 264407389
# likes                                                       16021542
# dislikes                                                      150990
# comment_count                                                6738565
# thumbnail_link        https://i.ytimg.com/vi/WMweEpGlu_U/default.jpg
# ...

# %% [markdown]
# total count of videos with respect to category

# %%
df.dtypes
# Out:
# video_id             object
# title                object
# publishedAt          object
# channelId            object
# channelTitle         object
# categoryId            int64
# trending_date        object
# tags                 object
# view_count            int64
# likes                 int64
# dislikes              int64
# comment_count         int64
# thumbnail_link       object
# comments_disabled      bool
# ratings_disabled       bool
# description          object
# video_category       object
# dtype: object

# %%
df.value_counts(['video_category'])
# Out:
# video_category
# Foreign                 58179
# Comedy                  28725
# Drama                   25269
# Family                  12640
# Shorts                   5286
# Sci-Fi/Fantasy           5029
# Horror                   4373
# Anime/Animation          4191
# Thriller                 3544
# Autos & Vehicles         3347
# Classics                  956
# Music                     894
# Science & Technology       87
# Shows                      73
# dtype: int64

# %%
#converting 2  date & time column  in propare format
df['publishedAt']=pd.to_datetime(df['publishedAt'])
df['trending_date']=pd.to_datetime(df['trending_date'])
df
# Out:
#            video_id                                              title  \
# 0       Iot0eF6EoNA  Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# 1       x-KbnJ9fvJc  Kya Baat Aa : Karan Aujla (Official Video) Tan...
# 2       KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 3       UsMRgnTcchY  Dil Ko Maine Di Kasam Video | Amaal M Ft.Ariji...
# 4       WNSEXJJhKTU  Baarish (Official Video) Payal Dev,Stebin Ben ...
# ...             ...                                                ...
# 152588  P1sAzjdFaAQ                   I STARTED A CONSTRUCTION COMPANY
# 152589  wNNM525464o  Gabbar ने दिया Hospital चलने वालों को मुंहतोड़...
# 152590  dsy0ogwdiZg       Ekkar Banegi Body Part 1 | Gym | ibrahim 420
# 152591  hQRxcSDRnWw      Shakti | शक्ति | Ep. 611 | Harman Is Attacked
# 152592  zM6s3JgF9_0  Paris Ka Trip (Video)  @Millind Gaba  X  @Yo Y...
#
#                      publishedAt                 channelId      channelTitle  \
# ...

# %%
df.dtypes
# Out:
# video_id                          object
# title                             object
# publishedAt          datetime64[ns, UTC]
# channelId                         object
# channelTitle                      object
# categoryId                         int64
# trending_date        datetime64[ns, UTC]
# tags                              object
# view_count                         int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link                    object
# comments_disabled                   bool
# ratings_disabled                    bool
# description                       object
# video_category                    object
# dtype: object

# %%
##checking for null values 
df.isnull().sum()
# Out:
# video_id                 0
# title                    0
# publishedAt              0
# channelId                0
# channelTitle             1
# categoryId               0
# trending_date            0
# tags                     0
# view_count               0
# likes                    0
# dislikes                 0
# comment_count            0
# thumbnail_link           0
# comments_disabled        0
# ratings_disabled         0
# description          16773
# video_category           0
# dtype: int64

# %%
#fill missing values
df['channelTitle']=df['channelTitle'].fillna('others')

# %%
#fill missing values
df['description']=df['description'].fillna('No discription')

# %%
df.isnull().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# likes                0
# dislikes             0
# comment_count        0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          0
# video_category       0
# dtype: int64

# %%
df.drop_duplicates('title',keep='last')
# Out:
#            video_id                                              title  \
# 90      n7C3aXBzM7s  நண்பா Mahesh Babu உனக்காக இது | Vijay VS Mahes...
# 91      lT6HV0Iweyo  कृष्ण जन्माष्टमी विशेष कीर्तन ! समाधान महाराज ...
# 115     ABrm1mQXj38  IPL 2020 - Patanjali IPL As Sponsor With 10 Bi...
# 116     nhO6cINEDs4            Gaadi Parking | Mirchi Murga | RJ Naved
# 118     aUTu0cjX4Uw  FilterCopy | When Your Younger Sister Starts D...
# ...             ...                                                ...
# 152588  P1sAzjdFaAQ                   I STARTED A CONSTRUCTION COMPANY
# 152589  wNNM525464o  Gabbar ने दिया Hospital चलने वालों को मुंहतोड़...
# 152590  dsy0ogwdiZg       Ekkar Banegi Body Part 1 | Gym | ibrahim 420
# 152591  hQRxcSDRnWw      Shakti | शक्ति | Ep. 611 | Harman Is Attacked
# 152592  zM6s3JgF9_0  Paris Ka Trip (Video)  @Millind Gaba  X  @Yo Y...
#
#                      publishedAt                 channelId  \
# ...

# %% [markdown]
# *start data Analysis*

# %% [markdown]
# category  with most view counts

# %%
df.head(5).T

# %%
df_view_analysis=df.groupby('video_category')['view_count'].sum().reset_index()
df_view_analysis
# Out:
#           video_category    view_count
# 0        Anime/Animation   12256128274
# 1       Autos & Vehicles   12107400329
# 2               Classics    1523350741
# 3                 Comedy  144019437825
# 4                  Drama   71303725669
# 5                 Family   38038250623
# 6                Foreign  162793384779
# 7                 Horror    4734824310
# 8                  Music    1487988710
# 9         Sci-Fi/Fantasy    8349640951
# 10  Science & Technology     995430847
# 11                Shorts   15545177288
# 12                 Shows      83440011
# 13              Thriller    7261514183

# %%
df_likes=df.groupby('video_category')['likes'].sum().reset_index()
df_likes
# Out:
#           video_category       likes
# 0        Anime/Animation   372824316
# 1       Autos & Vehicles   401380575
# 2               Classics   113643780
# 3                 Comedy  8126163621
# 4                  Drama  4458096488
# 5                 Family  2710583126
# 6                Foreign  7475993010
# 7                 Horror    94431618
# 8                  Music    76711878
# 9         Sci-Fi/Fantasy   483451858
# 10  Science & Technology    56458060
# 11                Shorts  1081698346
# 12                 Shows     4900339
# 13              Thriller   410665436

# %%
df_coment=df.groupby('video_category')['comment_count'].sum().reset_index()

# %%
df_view_analysis['Comment_count']=df_coment.comment_count
df_view_analysis
# Out:
#           video_category    view_count  Comment_count
# 0        Anime/Animation   12256128274       18532219
# 1       Autos & Vehicles   12107400329       20449204
# 2               Classics    1523350741        3790575
# 3                 Comedy  144019437825      914262141
# 4                  Drama   71303725669      104804465
# 5                 Family   38038250623       92097034
# 6                Foreign  162793384779      274269626
# 7                 Horror    4734824310       10313938
# 8                  Music    1487988710        1281716
# 9         Sci-Fi/Fantasy    8349640951       12315647
# 10  Science & Technology     995430847          95885
# 11                Shorts   15545177288       58302312
# 12                 Shows      83440011          63794
# 13              Thriller    7261514183       13610262

# %%
df_view_analysis['Likes']=df_likes.likes
df_view_analysis
# Out:
#           video_category    view_count       Likes
# 0        Anime/Animation   12256128274   372824316
# 1       Autos & Vehicles   12107400329   401380575
# 2               Classics    1523350741   113643780
# 3                 Comedy  144019437825  8126163621
# 4                  Drama   71303725669  4458096488
# 5                 Family   38038250623  2710583126
# 6                Foreign  162793384779  7475993010
# 7                 Horror    4734824310    94431618
# 8                  Music    1487988710    76711878
# 9         Sci-Fi/Fantasy    8349640951   483451858
# 10  Science & Technology     995430847    56458060
# 11                Shorts   15545177288  1081698346
# 12                 Shows      83440011     4900339
# 13              Thriller    7261514183   410665436

# %%
df_dislikes=df.groupby('video_category')['dislikes'].sum().reset_index()
df_view_analysis['Dislikes']=df_dislikes.dislikes

# %%
df_view_analysis
# Out:
#           video_category    view_count       Likes   Dislikes
# 0        Anime/Animation   12256128274   372824316    8723701
# 1       Autos & Vehicles   12107400329   401380575   18004648
# 2               Classics    1523350741   113643780    1132093
# 3                 Comedy  144019437825  8126163621  177940950
# 4                  Drama   71303725669  4458096488   42504145
# 5                 Family   38038250623  2710583126   36232633
# 6                Foreign  162793384779  7475993010  254035180
# 7                 Horror    4734824310    94431618   11479834
# 8                  Music    1487988710    76711878    1575311
# 9         Sci-Fi/Fantasy    8349640951   483451858    8072152
# 10  Science & Technology     995430847    56458060      13460
# 11                Shorts   15545177288  1081698346   21436172
# 12                 Shows      83440011     4900339      56038
# 13              Thriller    7261514183   410665436    5085234

# %%
df.value_counts(['channelTitle'])
# Out:
# channelTitle
# Vijay Television        1759
# Sourav Joshi Vlogs      1203
# Colors TV               1147
# Sony SAB                1028
# ZEE5                    1024
#                         ...
# Wanderers Hub Shorts       1
# Official Kashish PS        1
# OUTSPOKEN                  1
# EMPIRE VIDEO               1
# Akhil Music Official       1
# Length: 4010, dtype: int64

# %%
##group df by channel title
df_channel_group=df.groupby(by = df['channelTitle']).sum()
df_channel_group
# Out:
#                         categoryId  view_count     likes  dislikes  \
# channelTitle
# #RohiL Fitness Yug              68     2741126     51353      5153
# 1 Million Views Tamil         1518   107724641  10316469     43856
# 1.1 Gaming                     260     7581121    351014     32492
# 10 Mint Records                 50     4285070    438673      9285
# 10TV Entertainment             132     2434053     58670       642
# ...                            ...         ...       ...       ...
# ਪੰਜਾਬੀ ਲੋਕ Punjabi Lok         175     4108993    136619      5510
# తెలుగు రైతుబడి                 110     8556720    356449         0
# ಉದ್ಯೋಗ ಮಿತ್ರ                    81       60956      2513       162
# ആവൂസ് avoosss family           792    55219860   1438850         0
# ജോഷ് Talks                     616     8200112    438594     10530
#
#                         comment_count  comments_disabled  ratings_disabled
# channelTitle
# ...

# %%
##highest view count channel
df_channel_group[df_channel_group['view_count']==df_channel_group['view_count'].max()]
# Out:
#               categoryId   view_count      likes  dislikes  comment_count  \
# channelTitle
# T-Series            7307  17086546781  526523333  19816336       36989139
#
#               comments_disabled  ratings_disabled
# channelTitle
# T-Series                      0                 1

# %%
df_channel_group[df_channel_group['view_count']==df_channel_group['view_count'].min()]
# Out:
#                categoryId  view_count  likes  dislikes  comment_count  \
# channelTitle
# GoogleDoodles          16           0      0         0              0
#
#                comments_disabled  ratings_disabled
# channelTitle
# GoogleDoodles                 16                16

# %%
df_channel_group[df_channel_group['likes']==df_channel_group['likes'].max()]
# Out:
#               categoryId  view_count      likes  dislikes  comment_count  \
# channelTitle
# BLACKPINK           2264  7817129633  705022216  11275902      109132973
#
#               comments_disabled  ratings_disabled
# channelTitle
# BLACKPINK                     0                 0

# %%
df_channel_group['likes'].nlargest(5)
# Out:
# channelTitle
# BLACKPINK             705022216
# BANGTANTV             600182326
# Sourav Joshi Vlogs    583777244
# T-Series              526523333
# HYBE LABELS           507281287
# Name: likes, dtype: int64

# %%
df_channel_group[df_channel_group['dislikes']==df_channel_group['dislikes'].max()]
# Out:
#               categoryId  view_count    likes   dislikes  comment_count  \
# channelTitle
# FoxStarHindi         768   634673155  8667321  114251760       10217939
#
#               comments_disabled  ratings_disabled
# channelTitle
# FoxStarHindi                  0                 0

# %%
df_channel_group[df_channel_group['comment_count']==df_channel_group['comment_count'].max()]
# Out:
#               categoryId  view_count      likes  dislikes  comment_count  \
# channelTitle
# BLACKPINK           2264  7817129633  705022216  11275902      109132973
#
#               comments_disabled  ratings_disabled
# channelTitle
# BLACKPINK                     0                 0

# %% [markdown]
# **plotting graph**
# Analysis of chanel by highest  views, likes, dislikes, and comment, count.

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)

sns.barplot(x=df_channel_group['view_count'].nlargest(5).index,
           y=df_channel_group['view_count'].nlargest(5))
plt.title('Top 5 Highest view count channels', weight='bold',fontsize=12)
plt.xlabel('Channel Title',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,2)
sns.barplot(x=df_channel_group['likes'].nlargest(5).index,
           y=df_channel_group['likes'].nlargest(5))
plt.title('Top 5 Highest like count channels', weight='bold',fontsize=12)
plt.xlabel('Channel Title',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,3)
sns.barplot(x=df_channel_group['dislikes'].nlargest(5).index,
           y=df_channel_group['dislikes'].nlargest(5))
plt.title('Top 5 Highest Dislike count channels', weight='bold',fontsize=12)
plt.xlabel('Channel Title',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,4)
sns.barplot(x=df_channel_group['comment_count'].nlargest(5).index,
           y=df_channel_group['comment_count'].nlargest(5))
plt.title('Top 5 Highest comment count channels', weight='bold',fontsize=12)
plt.xlabel('Channel Title',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)
plt.show()

# %% [markdown]
# T-series seems to be most viewed channel in India. Sourav Joshi vlogs are present in each of the top contenders of views,likes and comments.
#
# FoxStarHindi leads the dislikes section reason being most disliked sadak 2 Movie trailer was from this channel. T-series with only being on in views not likes and comments finds itself in Disliked section.
#
# Most of the disliked videos are coming from Entertainment type of Channels like movie production or music company channels.
#
# BTS(Bangtan Sonyeondan - Korean Bulletproof Boy Scouts - Korean Pop Music Band) Channels are also leading in comments and likes with Korean girls channel Blackpink.

# %% [markdown]
# **plotting graph**
# Analysis of Category videos by highest  views, likes, dislikes, and comment, count.

# %%
df_video_category=df.groupby(by=df['video_category']).sum()
df_video_category
# Out:
#                       categoryId    view_count       likes   dislikes  \
# video_category
# Anime/Animation            71247   12256128274   372824316    8723701
# Autos & Vehicles            3347   12107400329   401380575   18004648
# Classics                   18164    1523350741   113643780    1132093
# Comedy                    368790  144019437825  8126163621  177940950
# Drama                     555918   71303725669  4458096488   42504145
# Family                    290720   38038250623  2710583126   36232633
# Foreign                  1396296  162793384779  7475993010  254035180
# Horror                    109325    4734824310    94431618   11479834
# Music                       1788    1487988710    76711878    1575311
# Sci-Fi/Fantasy            130754    8349640951   483451858    8072152
# Science & Technology        1305     995430847    56458060      13460
# Shorts                    148008   15545177288  1081698346   21436172
# ...

# %% [markdown]
# plotiong graph of top 5 highest view, like, dislike,comment count video category

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)

sns.barplot(x=df_video_category['view_count'].nlargest(5).index,
           y=df_video_category['view_count'].nlargest(5))
plt.title('Top 5 Highest view count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,2)
sns.barplot(x=df_video_category['likes'].nlargest(5).index,
           y=df_video_category['likes'].nlargest(5))
plt.title('Top 5 Highest like count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,3)
sns.barplot(x=df_video_category['dislikes'].nlargest(5).index,
           y=df_video_category['dislikes'].nlargest(5))
plt.title('Top 5 Highest Dislike count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)
plt.subplot(2,2,4)
sns.barplot(x=df_video_category['comment_count'].nlargest(5).index,
           y=df_video_category['comment_count'].nlargest(5))
plt.title('Top 5 Highest comment count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)
plt.show()

# %% [markdown]
# foreign and comedy leads with highest view and likes

# %% [markdown]
# **least wached category**

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,2,1)

sns.barplot(x=df_video_category['view_count'].nsmallest(5).index,
           y=df_video_category['view_count'].nsmallest(5))
plt.title('Top 5 least view count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,2)
sns.barplot(x=df_video_category['likes'].nsmallest(5).index,
           y=df_video_category['likes'].nsmallest(5))
plt.title('Top 5 leastst like count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,3)
sns.barplot(x=df_video_category['dislikes'].nsmallest(5).index,
           y=df_video_category['dislikes'].nsmallest(5))
plt.title('Top 5 least Dislike count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)

plt.subplot(2,2,4)
sns.barplot(x=df_video_category['comment_count'].nsmallest(5).index,
           y=df_video_category['comment_count'].nsmallest(5))
plt.title('Top 5 least comment count channels', weight='bold',fontsize=12)
plt.xlabel('Video Category',weight='bold',fontsize=10)
plt.ylabel('View_count',weight='bold',fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# shows are least watch category

# %% [markdown]
# ** create a Response percentage column which signifies the public response to a video and engagement b/w viewers and the video **

# %%
df_video_category['response_%']=round(((df_video_category.likes+df_video_category.dislikes)/(df_video_category.view_count)*100),2)

# %%
df_video_category.sort_values('response_%',ascending=False)
# Out:
#                       categoryId    view_count       likes   dislikes  \
# video_category
# Classics                   18164    1523350741   113643780    1132093
# Family                    290720   38038250623  2710583126   36232633
# Shorts                    148008   15545177288  1081698346   21436172
# Drama                     555918   71303725669  4458096488   42504145
# Shows                       2117      83440011     4900339      56038
# Sci-Fi/Fantasy            130754    8349640951   483451858    8072152
# Comedy                    368790  144019437825  8126163621  177940950
# Thriller                   95688    7261514183   410665436    5085234
# Science & Technology        1305     995430847    56458060      13460
# Music                       1788    1487988710    76711878    1575311
# Foreign                  1396296  162793384779  7475993010  254035180
# Autos & Vehicles            3347   12107400329   401380575   18004648
# ...

# %% [markdown]
# ploting graph of persantage responce of all category

# %%
plt.figure(figsize=(18,10))
sns.barplot(y=df_video_category['response_%'].index,
            x=df_video_category['response_%'])
plt.title('percentage response of video Category',weight='bold',fontsize=14)
plt.xlabel('public responce in %')
plt.ylabel('video category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Viewers are highly reacting to Classics, Drama, Family, Shots, Sci-fi/Fantacy Videos.

# %%
#highly reacting random videos
df_maxiview[df_maxiview.video_category.isin(['Classics','Drama'])].sample(5)
# Out:
#            video_id                                              title  \
# 50501   yzYTmoe2Md4                         Pura Din Game Khelra hai 😷
# 18774   4A7SrbqBsOw  Vegetable chop/Batata Vada/Simple Recipes/Aloo...
# 79638   xxXlWzBNrbc  अपने ही बच्चों में इतना भेदभाव क्यों? | Apne h...
# 134983  ClR8Wk9FntM  ఈ రోజు నా కండ్లు ఎందుకో కాటన్ చీర పైన పడ్డాయి ...
# 125134  Yx9_G_aFWAE  New trick😎😜😆😂#funny #shorts #comedy #koushalmonga
#
#                  publishedAt                 channelId           channelTitle  \
# 50501   2021-05-13T02:30:13Z  UCjvgGbPPn-FgYeguc5nxG4A     Sourav Joshi Vlogs
# 18774   2020-11-13T03:30:19Z  UC2adt1wOr6PvVkZyq6zv-3w             Fresh Food
# 79638   2021-09-29T03:59:19Z  UCCr5kt7Fe3TwglqwySNmIfw       Mr & Mrs Chauhan
# 134983  2022-07-13T04:35:21Z  UCv5qLJq__9_0u_Or5cXTdSw  Swathi Styles & Vlogs
# 125134  2022-05-18T05:30:08Z  UCgsdrGox82hP4o97-kt8sjg          Koushal Monga
#
#         categoryId         trending_date  \
# ...

# %% [markdown]
# Add column of %likes ,%dislikes, %comment count

# %%
df_view_analysis
# Out:
#           video_category    view_count       Likes   Dislikes
# 0        Anime/Animation   12256128274   372824316    8723701
# 1       Autos & Vehicles   12107400329   401380575   18004648
# 2               Classics    1523350741   113643780    1132093
# 3                 Comedy  144019437825  8126163621  177940950
# 4                  Drama   71303725669  4458096488   42504145
# 5                 Family   38038250623  2710583126   36232633
# 6                Foreign  162793384779  7475993010  254035180
# 7                 Horror    4734824310    94431618   11479834
# 8                  Music    1487988710    76711878    1575311
# 9         Sci-Fi/Fantasy    8349640951   483451858    8072152
# 10  Science & Technology     995430847    56458060      13460
# 11                Shorts   15545177288  1081698346   21436172
# 12                 Shows      83440011     4900339      56038
# 13              Thriller    7261514183   410665436    5085234

# %%
#calculate % likes
df_view_analysis['likes_%']=round(((df_view_analysis.Likes)/(df_view_analysis.view_count))*100,2)
df_view_analysis

# %%
#calculate and add column dislike % and comment count %
df_view_analysis['dislikes_%']=round(((df_view_analysis.Dislikes)/(df_view_analysis.view_count))*100,2)
df_view_analysis['comment_count_%']=round(((df_view_analysis.Comment_count)/(df_view_analysis.view_count))*100,2)

# %%
df_view_analysis
# Out:
#           video_category    view_count       Likes   Dislikes  likes_%  \
# 0        Anime/Animation   12256128274   372824316    8723701     3.04
# 1       Autos & Vehicles   12107400329   401380575   18004648     3.32
# 2               Classics    1523350741   113643780    1132093     7.46
# 3                 Comedy  144019437825  8126163621  177940950     5.64
# 4                  Drama   71303725669  4458096488   42504145     6.25
# 5                 Family   38038250623  2710583126   36232633     7.13
# 6                Foreign  162793384779  7475993010  254035180     4.59
# 7                 Horror    4734824310    94431618   11479834     1.99
# 8                  Music    1487988710    76711878    1575311     5.16
# 9         Sci-Fi/Fantasy    8349640951   483451858    8072152     5.79
# 10  Science & Technology     995430847    56458060      13460     5.67
# 11                Shorts   15545177288  1081698346   21436172     6.96
# ...

# %%
#ploting graph
plt.figure(figsize=(20,10))

df_view_analysis.plot(x="video_category",
                       y=["likes_%", "dislikes_%", "comment_count_%"], kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='video_category'>

# %% [markdown]
# LIkes % vs Type of videos (video category)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_view_analysis['video_category'],y=df_view_analysis['likes_%'])
plt.title('Likes of video category in percentage', fontsize=14,weight='bold')
plt.show()

# %% [markdown]
# classics, family and shorts are the video category with high likes

# %% [markdown]
# **Dislike%  of video category**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_view_analysis['video_category'],
             y=df_view_analysis['dislikes_%'])
plt.title('Dislikes of video category in percentage', fontsize=14,weight='bold')
plt.show()

# %% [markdown]
# Horror  video category is highly disliked

# %% [markdown]
# **comment count of vedio category in percentage**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_view_analysis['video_category'],
             y=df_view_analysis['comment_count_%'])
plt.title('Comment count  of video category in percentage', fontsize=14,weight='bold')
plt.show()

# %% [markdown]
# comedy video category is having high comments

# %% [markdown]
# **Channel Analysis**

# %%
#group by channel title with view count,likes and dislikes
df_channel=df_maxiview.groupby('channelTitle')['view_count'].sum().reset_index()
df_channel_likes=df_maxiview.groupby('channelTitle')['likes'].sum().reset_index()
df_channel_dislikes=df_maxiview.groupby('channelTitle')['dislikes'].sum().reset_index()
df_channel_comm=df_maxiview.groupby('channelTitle')['comment_count'].sum().reset_index()

# %%
#adding likes,dislike, and comment  column to df_channel
df_channel['likes']=df_channel_likes.likes
df_channel

# %%
df_channel['dislikes']=df_channel_dislikes.dislikes
df_channel['comment_count']=df_channel_comm.comment_count
df_channel

# %%
#sorting with top 15 highly view channels
df_channel.sort_values('view_count',ascending=False)[:15:]

# %%
#plotting graph of channel vs view_count
df_channel_view=df_channel.sort_values('view_count',ascending=False)[:15:]

plt.figure(figsize=(24,10))

sns.barplot(x=df_channel_view['channelTitle'],y=df_channel_view['view_count'])
plt.title('channels view count',weight='bold',fontsize=18,color='maroon')
plt.xlabel('Channel Title',weight='bold',fontsize=15)
plt.ylabel(' view count',weight='bold',fontsize=15)
plt.show()

# %% [markdown]
# T-series is highest view channel folloed by vijaya television and sourav joshi vlogs

# %%
df_channel['likes']=df_channel_likes.likes
df_channel

# %%
#ploting graph of channel title vs likes
df_channel_like=df_channel.sort_values('likes',ascending=False)[:15:]

plt.figure(figsize=(24,10))

sns.barplot(x=df_channel_like['channelTitle'],y=df_channel_like['likes'])
plt.title('Highest liked channels',weight='bold',fontsize=18,color='maroon')
plt.xlabel('Channel Title',weight='bold',fontsize=15)
plt.ylabel('Like Count',weight='bold',fontsize=15)
plt.show()

# %% [markdown]
# It seems that sourav joshi channel got most likes.

# %%
#graph of dislike channels
df_channel_dislike=df_channel.sort_values('dislikes',ascending=False)[:15:]

plt.figure(figsize=(24,10))

sns.barplot(x=df_channel_dislike['channelTitle'],y=df_channel_dislike['dislikes'])
plt.title('Disliked channels',weight='bold',fontsize=18,color='maroon')
plt.xlabel('Channel Title',weight='bold',fontsize=15)
plt.ylabel('Disike Count',weight='bold',fontsize=15)
plt.show()

# %% [markdown]
# fox star hindi channel got highest dislikes

# %%
#plotting graph of comment countvs channel titke
df_channel_comment=df_channel.sort_values('comment_count',ascending=False)[:15:]

plt.figure(figsize=(24,10))

sns.barplot(x=df_channel_comment['channelTitle'],y=df_channel_comment['comment_count'])
plt.title('Channel Title vs Comment Count',weight='bold',fontsize=18,color='maroon')
plt.xlabel('Channel Title',weight='bold',fontsize=15)
plt.ylabel('Comment Count',weight='bold',fontsize=15)
plt.show()

# %% [markdown]
# **Channels that have their videos in trending for most of the times.**

# %%
NOofDaysInTrending=df.groupby('video_id')['view_count'].count()
NOofDaysInTrending
# Out:
# video_id
# --9rRxqTdjQ    4
# --GS_EPuuMc    3
# --L_wDHUaxY    4
# --WGlFF6-yw    5
# --vmXGvtqxQ    4
#               ..
# zz8pzT847II    3
# zzCrFWjKPy8    3
# zzYIDcNggBM    3
# zzgLDNpZ8ew    4
# zzyTrU2IJsQ    1
# Name: view_count, Length: 46294, dtype: int64

# %%
#defining function 
def fectch_video_times(value):
    return NOofDaysInTrending[value]

# %%
df_maxiview['times_in_trending']=df_maxiview.video_id.apply(fectch_video_times)
df_maxiview.sample(5).T

# %% [markdown]
# TOP 25 videos that are in treanding for many days

# %%
df_trend_videos=df_maxiview.sort_values('times_in_trending',ascending=False)[:15:]
df_trend_videos

# %% [markdown]
# Top channels whose video is in treanding for most time

# %%
#plotting graph
plt.figure(figsize=(25,10))
sns.barplot(x=df_trend_videos['channelTitle'],y=df_trend_videos['times_in_trending'])
plt.title('channel vs No. of times Trending',fontsize=18,weight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
df.head(5).T
# Out:
#                                                                    0  \
# video_id                                                 Iot0eF6EoNA
# title              Sadak 2 | Official Trailer | Sanjay | Pooja | ...
# publishedAt                                2020-08-12 04:31:41+00:00
# channelId                                   UCGqvJPRcv7aVFun-eTsatcA
# channelTitle                                            FoxStarHindi
# categoryId                                                        24
# trending_date                              2020-08-12 00:00:00+00:00
# tags               sadak|sadak 2|mahesh bhatt|vishesh films|pooja...
# view_count                                                   9885899
# likes                                                         224925
# dislikes                                                     3979409
# comment_count                                                 350210
# thumbnail_link        https://i.ytimg.com/vi/Iot0eF6EoNA/default.jpg
# ...

# %% [markdown]
# **Comment Disable video category**

# %%
#video category with comment disable
df_disable=df.groupby('video_category')['comments_disabled'].sum().reset_index()
df_disable
# Out:
#           video_category  comments_disabled
# 0        Anime/Animation                 12
# 1       Autos & Vehicles                 23
# 2               Classics                  5
# 3                 Comedy                 57
# 4                  Drama                305
# 5                 Family                 84
# 6                Foreign                501
# 7                 Horror                187
# 8                  Music                  4
# 9         Sci-Fi/Fantasy                 17
# 10  Science & Technology                  0
# 11                Shorts                184
# 12                 Shows                  0
# 13              Thriller                  2

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=df_disable['video_category'],y=df_disable['comments_disabled'])
plt.title('Video Category vs Comment disable',fontsize=18,weight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# foreign category leads in disabled comments followed by drama
